# %%
from scipy.stats import wilcoxon
# We use Wilcoxon signed-rank test because it is well-suited for paired data with non-normally distributed differences

# %%
import numpy as np
# DT4LM = np.array([])
# Baseline = np.array([])
# res = wilcoxon(DT4LM, Baseline, alternative='greater')

# %%
# res
